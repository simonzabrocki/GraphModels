# %%
from graphmodels.graphmodel import GraphModel
from graphmodels.utils import parse_model_data
from models.Hermen.model_H_1 import model_H_1

# %%
inputs, parameters = parse_model_data('models/Hermen/model_H_1_data.json')
G_H = GraphModel(model_H_1)
X = G_H.run(inputs, parameters)
G_H.draw()
# Out:
# /home/simon/GreenGrowthInstitute/GraphModels/models/Hermen/model_H_1.py:34: RuntimeWarning: invalid value encountered in true_divide
#   'formula': lambda X: np.nan_to_num((100 * X['FPi']) / (X['FPi'] - X['FEi'] + X['FIi']))}  # For now leave the formula field empty
# /home/simon/GreenGrowthInstitute/GraphModels/models/Hermen/model_H_1.py:25: RuntimeWarning: invalid value encountered in true_divide
#   'formula': lambda X: (X['FDKC2017_i'] / (X['FDKG2017_i'] / 365))}  # For now leave the formula field empty
# /home/simon/GreenGrowthInstitute/GraphModels/models/Hermen/model_H_1.py:104: RuntimeWarning: invalid value encountered in true_divide
#   'formula': lambda X: np.nan_to_num((X['TCDi'] * X['SSRi'] / 100 * 365) / X['KKRi'])}  # For now leave the formula field empty
